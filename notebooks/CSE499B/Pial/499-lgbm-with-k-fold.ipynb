# %%
import numpy as np
import pandas as pd
import gc
import re
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# Preprocess application_train.csv and application_test.csv
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv('../input/home-credit-default-risk/application_train.csv', nrows= num_rows)
    test_df = pd.read_csv('../input/home-credit-default-risk/application_test.csv', nrows= num_rows)
    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = df.append(test_df).reset_index()
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']
    
    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    
    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)
    # Some simple new features (percentages)
    df['DAYS_EMPLOYED_PERC'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['INCOME_CREDIT_PERC'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']
    df['INCOME_PER_PERSON'] = df['AMT_INCOME_TOTAL'] / df['CNT_FAM_MEMBERS']
    df['ANNUITY_INCOME_PERC'] = df['AMT_ANNUITY'] / df['AMT_INCOME_TOTAL']
    df['PAYMENT_RATE'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']
    del test_df
    gc.collect()
    return df

# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv('../input/home-credit-default-risk/bureau.csv', nrows = num_rows)
    bb = pd.read_csv('../input/home-credit-default-risk/bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)
    
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()
    
    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['max', 'mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
    
    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

    

# Preprocess credit_card_balance.csv
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv('../input/home-credit-default-risk/credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

# LightGBM GBDT with KFold or Stratified KFold
def kfold_lightgbm(df, num_folds, stratified = False, debug= False):
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    df = df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
    df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in df.columns]
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=1001)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        # LightGBM parameters found by Bayesian optimization
        clf = LGBMClassifier(
            nthread=4,
            n_estimators=10000,
            learning_rate=0.02,
            num_leaves=34,
            colsample_bytree=0.9497036,
            subsample=0.8715623,
            max_depth=8,
            reg_alpha=0.041545473,
            reg_lambda=0.0735294,
            min_split_gain=0.0222415,
            min_child_weight=39.3259775,
            silent=-1,
            verbose=-1, )

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= 200, early_stopping_rounds= 200)

        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]
        sub_preds += clf.predict_proba(test_df[feats], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()

    print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
    # Write submission file and plot feature importance
    if not debug:
        test_df['TARGET'] = sub_preds
        test_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)
    display_importances(feature_importance_df)
    return feature_importance_df

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances01.png')


def main(debug = False):
    num_rows = 10000 if debug else None
    df = application_train_test(num_rows)
    df = df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
    df.columns = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in df.columns]
    with timer("Process bureau and bureau_balance"):
        bureau = bureau_and_balance(num_rows)
        print("Bureau df shape:", bureau.shape)
        df = df.join(bureau, how='left', on='SK_ID_CURR')
        del bureau
        gc.collect()
    
    with timer("Process credit card balance"):
        cc = credit_card_balance(num_rows)
        print("Credit card balance df shape:", cc.shape)
        df = df.join(cc, how='left', on='SK_ID_CURR')
        del cc
        gc.collect()
    with timer("Run LightGBM with kfold"):
        feat_importance = kfold_lightgbm(df, num_folds= 10, stratified= False, debug= debug)

if __name__ == "__main__":
    submission_file_name = "submission_kernel02.csv"
    with timer("Full model run"):
        main()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# Train samples: 307511, test samples: 48744
# Bureau df shape: (305811, 116)
# Process bureau and bureau_balance - done in 27s
# Credit card balance df shape: (103558, 141)
# Process credit card balance - done in 24s
# Starting LightGBM. Train shape: (307507, 505), test shape: (48744, 505)
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.784067	training's binary_logloss: 0.238631	valid_1's auc: 0.768127	valid_1's binary_logloss: 0.248814
# [400]	training's auc: 0.804969	training's binary_logloss: 0.230703	valid_1's auc: 0.777115	valid_1's binary_logloss: 0.24552
# [600]	training's auc: 0.818688	training's binary_logloss: 0.225563	valid_1's auc: 0.780407	valid_1's binary_logloss: 0.244386
# [800]	training's auc: 0.829572	training's binary_logloss: 0.221437	valid_1's auc: 0.78209	valid_1's binary_logloss: 0.243804
# [1000]	training's auc: 0.839141	training's binary_logloss: 0.217761	valid_1's auc: 0.783044	valid_1's binary_logloss: 0.243485
# [1200]	training's auc: 0.847726	training's binary_logloss: 0.214324	valid_1's auc: 0.783544	valid_1's binary_logloss: 0.243282
# [1400]	training's auc: 0.855617	training's binary_logloss: 0.211087	valid_1's auc: 0.783826	valid_1's binary_logloss: 0.24321
# [1600]	training's auc: 0.862739	training's binary_logloss: 0.208064	valid_1's auc: 0.783752	valid_1's binary_logloss: 0.243246
# Early stopping, best iteration is:
# [1424]	training's auc: 0.856454	training's binary_logloss: 0.210733	valid_1's auc: 0.783957	valid_1's binary_logloss: 0.243182
# Fold  1 AUC : 0.783957
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.78416	training's binary_logloss: 0.23918	valid_1's auc: 0.766709	valid_1's binary_logloss: 0.244319
# [400]	training's auc: 0.804795	training's binary_logloss: 0.231267	valid_1's auc: 0.775397	valid_1's binary_logloss: 0.240854
# [600]	training's auc: 0.81855	training's binary_logloss: 0.226085	valid_1's auc: 0.778522	valid_1's binary_logloss: 0.239688
# [800]	training's auc: 0.829697	training's binary_logloss: 0.221863	valid_1's auc: 0.779847	valid_1's binary_logloss: 0.239151
# [1000]	training's auc: 0.839296	training's binary_logloss: 0.218139	valid_1's auc: 0.780604	valid_1's binary_logloss: 0.238898
# [1200]	training's auc: 0.848084	training's binary_logloss: 0.214651	valid_1's auc: 0.781	valid_1's binary_logloss: 0.238706
# Early stopping, best iteration is:
# [1147]	training's auc: 0.845932	training's binary_logloss: 0.215539	valid_1's auc: 0.781093	valid_1's binary_logloss: 0.23871
# Fold  2 AUC : 0.781093
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.784758	training's binary_logloss: 0.238621	valid_1's auc: 0.75958	valid_1's binary_logloss: 0.248889
# [400]	training's auc: 0.805314	training's binary_logloss: 0.230768	valid_1's auc: 0.76877	valid_1's binary_logloss: 0.245838
# [600]	training's auc: 0.819231	training's binary_logloss: 0.225573	valid_1's auc: 0.77183	valid_1's binary_logloss: 0.244839
# [800]	training's auc: 0.830079	training's binary_logloss: 0.221472	valid_1's auc: 0.773226	valid_1's binary_logloss: 0.244378
# [1000]	training's auc: 0.839785	training's binary_logloss: 0.217724	valid_1's auc: 0.773947	valid_1's binary_logloss: 0.244172
# [1200]	training's auc: 0.8481	training's binary_logloss: 0.214383	valid_1's auc: 0.774405	valid_1's binary_logloss: 0.244063
# Early stopping, best iteration is:
# [1178]	training's auc: 0.847335	training's binary_logloss: 0.214687	valid_1's auc: 0.774452	valid_1's binary_logloss: 0.244055
# Fold  3 AUC : 0.774452
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.784186	training's binary_logloss: 0.239222	valid_1's auc: 0.769865	valid_1's binary_logloss: 0.243476
# [400]	training's auc: 0.804255	training's binary_logloss: 0.23147	valid_1's auc: 0.779638	valid_1's binary_logloss: 0.239767
# [600]	training's auc: 0.817786	training's binary_logloss: 0.226421	valid_1's auc: 0.783128	valid_1's binary_logloss: 0.238524
# [800]	training's auc: 0.82891	training's binary_logloss: 0.222249	valid_1's auc: 0.784811	valid_1's binary_logloss: 0.237977
# [1000]	training's auc: 0.838975	training's binary_logloss: 0.218442	valid_1's auc: 0.785998	valid_1's binary_logloss: 0.237611
# [1200]	training's auc: 0.84795	training's binary_logloss: 0.214857	valid_1's auc: 0.786533	valid_1's binary_logloss: 0.237485
# [1400]	training's auc: 0.855979	training's binary_logloss: 0.211588	valid_1's auc: 0.786811	valid_1's binary_logloss: 0.237393
# [1600]	training's auc: 0.863512	training's binary_logloss: 0.208451	valid_1's auc: 0.787003	valid_1's binary_logloss: 0.237371
# [1800]	training's auc: 0.870322	training's binary_logloss: 0.205474	valid_1's auc: 0.787498	valid_1's binary_logloss: 0.237234
# Early stopping, best iteration is:
# [1793]	training's auc: 0.870068	training's binary_logloss: 0.205585	valid_1's auc: 0.787533	valid_1's binary_logloss: 0.23722
# Fold  4 AUC : 0.787533
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.783954	training's binary_logloss: 0.240006	valid_1's auc: 0.768083	valid_1's binary_logloss: 0.237038
# [400]	training's auc: 0.804926	training's binary_logloss: 0.231933	valid_1's auc: 0.776673	valid_1's binary_logloss: 0.233742
# [600]	training's auc: 0.818739	training's binary_logloss: 0.226717	valid_1's auc: 0.779613	valid_1's binary_logloss: 0.232753
# [800]	training's auc: 0.829782	training's binary_logloss: 0.222556	valid_1's auc: 0.781245	valid_1's binary_logloss: 0.232217
# [1000]	training's auc: 0.839127	training's binary_logloss: 0.218897	valid_1's auc: 0.781743	valid_1's binary_logloss: 0.232012
# [1200]	training's auc: 0.847652	training's binary_logloss: 0.215463	valid_1's auc: 0.78239	valid_1's binary_logloss: 0.231843
# [1400]	training's auc: 0.855669	training's binary_logloss: 0.2122	valid_1's auc: 0.782455	valid_1's binary_logloss: 0.231816
# Early stopping, best iteration is:
# [1231]	training's auc: 0.848929	training's binary_logloss: 0.21496	valid_1's auc: 0.782652	valid_1's binary_logloss: 0.23177
# Fold  5 AUC : 0.782652
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.785107	training's binary_logloss: 0.238964	valid_1's auc: 0.7579	valid_1's binary_logloss: 0.245608
# [400]	training's auc: 0.805461	training's binary_logloss: 0.231152	valid_1's auc: 0.766872	valid_1's binary_logloss: 0.242523
# [600]	training's auc: 0.819406	training's binary_logloss: 0.22591	valid_1's auc: 0.770597	valid_1's binary_logloss: 0.241375
# [800]	training's auc: 0.83059	training's binary_logloss: 0.221666	valid_1's auc: 0.772219	valid_1's binary_logloss: 0.240857
# [1000]	training's auc: 0.840155	training's binary_logloss: 0.217893	valid_1's auc: 0.773124	valid_1's binary_logloss: 0.240587
# [1200]	training's auc: 0.848747	training's binary_logloss: 0.214428	valid_1's auc: 0.773493	valid_1's binary_logloss: 0.240489
# [1400]	training's auc: 0.85701	training's binary_logloss: 0.210966	valid_1's auc: 0.773625	valid_1's binary_logloss: 0.240468
# [1600]	training's auc: 0.864182	training's binary_logloss: 0.207932	valid_1's auc: 0.774005	valid_1's binary_logloss: 0.240383
# Early stopping, best iteration is:
# [1575]	training's auc: 0.863229	training's binary_logloss: 0.208326	valid_1's auc: 0.773999	valid_1's binary_logloss: 0.240374
# Fold  6 AUC : 0.773999
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.784274	training's binary_logloss: 0.239251	valid_1's auc: 0.765407	valid_1's binary_logloss: 0.243463
# [400]	training's auc: 0.805036	training's binary_logloss: 0.231297	valid_1's auc: 0.77527	valid_1's binary_logloss: 0.239981
# [600]	training's auc: 0.818375	training's binary_logloss: 0.226277	valid_1's auc: 0.777959	valid_1's binary_logloss: 0.239045
# [800]	training's auc: 0.829248	training's binary_logloss: 0.222195	valid_1's auc: 0.779025	valid_1's binary_logloss: 0.238661
# [1000]	training's auc: 0.838788	training's binary_logloss: 0.218511	valid_1's auc: 0.779873	valid_1's binary_logloss: 0.238417
# [1200]	training's auc: 0.847491	training's binary_logloss: 0.215066	valid_1's auc: 0.779912	valid_1's binary_logloss: 0.238426
# Early stopping, best iteration is:
# [1131]	training's auc: 0.84449	training's binary_logloss: 0.21625	valid_1's auc: 0.780019	valid_1's binary_logloss: 0.238384
# Fold  7 AUC : 0.780019
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.784233	training's binary_logloss: 0.238858	valid_1's auc: 0.763258	valid_1's binary_logloss: 0.247353
# [400]	training's auc: 0.804519	training's binary_logloss: 0.231069	valid_1's auc: 0.773609	valid_1's binary_logloss: 0.243698
# [600]	training's auc: 0.818179	training's binary_logloss: 0.22602	valid_1's auc: 0.777178	valid_1's binary_logloss: 0.242468
# [800]	training's auc: 0.829227	training's binary_logloss: 0.221825	valid_1's auc: 0.778967	valid_1's binary_logloss: 0.241868
# [1000]	training's auc: 0.8388	training's binary_logloss: 0.218131	valid_1's auc: 0.779962	valid_1's binary_logloss: 0.241546
# [1200]	training's auc: 0.847539	training's binary_logloss: 0.214625	valid_1's auc: 0.780855	valid_1's binary_logloss: 0.241295
# [1400]	training's auc: 0.856185	training's binary_logloss: 0.21113	valid_1's auc: 0.780951	valid_1's binary_logloss: 0.241249
# Early stopping, best iteration is:
# [1313]	training's auc: 0.852479	training's binary_logloss: 0.212666	valid_1's auc: 0.781039	valid_1's binary_logloss: 0.241249
# Fold  8 AUC : 0.781039
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.783424	training's binary_logloss: 0.239208	valid_1's auc: 0.77167	valid_1's binary_logloss: 0.244722
# [400]	training's auc: 0.804323	training's binary_logloss: 0.231278	valid_1's auc: 0.780285	valid_1's binary_logloss: 0.241268
# [600]	training's auc: 0.818135	training's binary_logloss: 0.226115	valid_1's auc: 0.783111	valid_1's binary_logloss: 0.240139
# [800]	training's auc: 0.829211	training's binary_logloss: 0.221957	valid_1's auc: 0.784773	valid_1's binary_logloss: 0.239532
# [1000]	training's auc: 0.839137	training's binary_logloss: 0.218132	valid_1's auc: 0.785403	valid_1's binary_logloss: 0.239275
# [1200]	training's auc: 0.848464	training's binary_logloss: 0.214477	valid_1's auc: 0.785964	valid_1's binary_logloss: 0.239076
# [1400]	training's auc: 0.856628	training's binary_logloss: 0.211174	valid_1's auc: 0.786014	valid_1's binary_logloss: 0.239046
# [1600]	training's auc: 0.863908	training's binary_logloss: 0.208121	valid_1's auc: 0.786211	valid_1's binary_logloss: 0.238984
# [1800]	training's auc: 0.870502	training's binary_logloss: 0.205271	valid_1's auc: 0.786049	valid_1's binary_logloss: 0.239028
# Early stopping, best iteration is:
# [1609]	training's auc: 0.864294	training's binary_logloss: 0.207968	valid_1's auc: 0.786224	valid_1's binary_logloss: 0.238983
# Fold  9 AUC : 0.786224
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 200 rounds
# [200]	training's auc: 0.784223	training's binary_logloss: 0.239392	valid_1's auc: 0.762886	valid_1's binary_logloss: 0.24316
# [400]	training's auc: 0.804723	training's binary_logloss: 0.231608	valid_1's auc: 0.772405	valid_1's binary_logloss: 0.239687
# [600]	training's auc: 0.818677	training's binary_logloss: 0.226375	valid_1's auc: 0.775441	valid_1's binary_logloss: 0.238567
# [800]	training's auc: 0.829725	training's binary_logloss: 0.222183	valid_1's auc: 0.776678	valid_1's binary_logloss: 0.23805
# [1000]	training's auc: 0.839313	training's binary_logloss: 0.21845	valid_1's auc: 0.777601	valid_1's binary_logloss: 0.237692
# [1200]	training's auc: 0.847813	training's binary_logloss: 0.215057	valid_1's auc: 0.777812	valid_1's binary_logloss: 0.237597
# [1400]	training's auc: 0.855647	training's binary_logloss: 0.211852	valid_1's auc: 0.777977	valid_1's binary_logloss: 0.237514
# [1600]	training's auc: 0.862825	training's binary_logloss: 0.208723	valid_1's auc: 0.77819	valid_1's binary_logloss: 0.237464
# Early stopping, best iteration is:
# [1586]	training's auc: 0.862365	training's binary_logloss: 0.208926	valid_1's auc: 0.778263	valid_1's binary_logloss: 0.237433
# Fold 10 AUC : 0.778263
# Full AUC score 0.780912
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Run LightGBM with kfold - done in 3045s
# Full model run - done in 3104s
