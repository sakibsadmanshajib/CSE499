# %%
import os
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
import gc
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
DATA_DIRECTORY = ""

# %%
train = pd.read_csv(os.path.join(DATA_DIRECTORY, 'train.csv'))
test = pd.read_csv(os.path.join(DATA_DIRECTORY, 'test.csv'))
labels = pd.read_csv(os.path.join(DATA_DIRECTORY, 'labels.csv'))

# %%
labels = labels.to_numpy()

# %%
def model(features, test_features, labels, n_folds = 5):
    
    # Extract the ids
    train_ids = features['SK_ID_CURR']
    test_ids = test_features['SK_ID_CURR']
    
    # Remove the ids and target
    features = features.drop(columns = ['SK_ID_CURR'])
    test_features = test_features.drop(columns = ['SK_ID_CURR'])
    
    
    cat_indices = 'auto'
        
    print('Training Data Shape: ', features.shape)
    print('Testing Data Shape: ', test_features.shape)
    
    
    # Convert to np arrays
    features = np.array(features)
    test_features = np.array(test_features)
    
    # Create the kfold object
    k_fold = KFold(n_splits = n_folds, shuffle = True, random_state = 50)
    
    # Empty array for test predictions
    test_predictions = np.zeros(test_features.shape[0])
    
    # Empty array for out of fold validation predictions
    out_of_fold = np.zeros(features.shape[0])
    
    # Lists for recording validation and training scores
    valid_scores = []
    train_scores = []
    
    # Iterate through each fold
    for train_indices, valid_indices in k_fold.split(features):
        
        # Training data for the fold
        train_features, train_labels = features[train_indices], labels[train_indices]
        # Validation data for the fold
        valid_features, valid_labels = features[valid_indices], labels[valid_indices]
        
        params = {'random_state': 8888, 'nthread': -1}
        # Create the model
        model = lgb.LGBMClassifier(**{**params, **LIGHTGBM_PARAMS})
        
        # Train the model
        model.fit(train_features, train_labels, eval_metric = 'auc',
                  eval_set = [(valid_features, valid_labels), (train_features, train_labels)],
                  eval_names = ['valid', 'train'], categorical_feature = cat_indices,
                  early_stopping_rounds = 100, verbose = 200)
        
        # Record the best iteration
        best_iteration = model.best_iteration_
        
        # Make predictions
        test_predictions += model.predict_proba(test_features, num_iteration = best_iteration)[:, 1] / k_fold.n_splits
        
        # Record the out of fold predictions
        out_of_fold[valid_indices] = model.predict_proba(valid_features, num_iteration = best_iteration)[:, 1]
        
        # Record the best score
        valid_score = model.best_score_['valid']['auc']
        train_score = model.best_score_['train']['auc']
        
        valid_scores.append(valid_score)
        train_scores.append(train_score)
        
        # Clean up memory
        gc.enable()
        del model, train_features, valid_features
        gc.collect()
        
    # Make the submission dataframe
    submission = pd.DataFrame({'SK_ID_CURR': test_ids, 'TARGET': test_predictions})
    
    # Overall validation score
    valid_auc = roc_auc_score(labels, out_of_fold)
    
    # Add the overall scores to the metrics
    valid_scores.append(valid_auc)
    train_scores.append(np.mean(train_scores))
    
    # Needed for creating dataframe of validation scores
    fold_names = list(range(n_folds))
    fold_names.append('overall')
    
    # Dataframe of validation scores
    metrics = pd.DataFrame({'fold': fold_names,
                            'train': train_scores,
                            'valid': valid_scores}) 
    
    return submission, metrics

# %%
LIGHTGBM_PARAMS = {
    'boosting_type': 'goss',
    'n_estimators': 10000,
    'learning_rate': 0.005134,
    'num_leaves': 54,
    'max_depth': 10,
    'subsample_for_bin': 240000,
    'reg_alpha': 0.436193,
    'reg_lambda': 0.479169,
    'colsample_bytree': 0.508716,
    'min_split_gain': 0.024766,
    'subsample': 1,
    'is_unbalance': False,
    'silent':-1,
    'verbose':-1
}

# %%
submission, metrics = model(train, test, labels)
print('LightGBM metrics')
print(metrics)
# Out:
# Training Data Shape:  (307506, 657)
# Testing Data Shape:  (48744, 657)
# C:\Users\sakib\anaconda3\envs\CSE499\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=-1 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [200]	train's auc: 0.780177	train's binary_logloss: 0.248548	valid's auc: 0.757979	valid's binary_logloss: 0.250784
# [400]	train's auc: 0.803354	train's binary_logloss: 0.236692	valid's auc: 0.769293	valid's binary_logloss: 0.243274
# [600]	train's auc: 0.819102	train's binary_logloss: 0.229269	valid's auc: 0.777341	valid's binary_logloss: 0.239534
# [800]	train's auc: 0.831547	train's binary_logloss: 0.223574	valid's auc: 0.783028	valid's binary_logloss: 0.237241
# [1000]	train's auc: 0.841869	train's binary_logloss: 0.218877	valid's auc: 0.786676	valid's binary_logloss: 0.235787
# [1200]	train's auc: 0.851192	train's binary_logloss: 0.214717	valid's auc: 0.789287	valid's binary_logloss: 0.23478
# [1400]	train's auc: 0.859779	train's binary_logloss: 0.210919	valid's auc: 0.791141	valid's binary_logloss: 0.234075
# [1600]	train's auc: 0.867744	train's binary_logloss: 0.207393	valid's auc: 0.79257	valid's binary_logloss: 0.233529
# [1800]	train's auc: 0.875232	train's binary_logloss: 0.204055	valid's auc: 0.79347	valid's binary_logloss: 0.233168
# [2000]	train's auc: 0.882335	train's binary_logloss: 0.200875	valid's auc: 0.794213	valid's binary_logloss: 0.232884
# [2200]	train's auc: 0.888993	train's binary_logloss: 0.197828	valid's auc: 0.794918	valid's binary_logloss: 0.23263
# [2400]	train's auc: 0.895337	train's binary_logloss: 0.194915	valid's auc: 0.795398	valid's binary_logloss: 0.232459
# [2600]	train's auc: 0.90119	train's binary_logloss: 0.192109	valid's auc: 0.795687	valid's binary_logloss: 0.232342
# [2800]	train's auc: 0.906762	train's binary_logloss: 0.189387	valid's auc: 0.795922	valid's binary_logloss: 0.23224
# [3000]	train's auc: 0.911926	train's binary_logloss: 0.186776	valid's auc: 0.796167	valid's binary_logloss: 0.232134
# [3200]	train's auc: 0.916859	train's binary_logloss: 0.184228	valid's auc: 0.796373	valid's binary_logloss: 0.232038
# [3400]	train's auc: 0.92153	train's binary_logloss: 0.181763	valid's auc: 0.796429	valid's binary_logloss: 0.232012
# [3600]	train's auc: 0.925895	train's binary_logloss: 0.179333	valid's auc: 0.796546	valid's binary_logloss: 0.231963
# [3800]	train's auc: 0.930039	train's binary_logloss: 0.176988	valid's auc: 0.796761	valid's binary_logloss: 0.23189
# [4000]	train's auc: 0.933979	train's binary_logloss: 0.17469	valid's auc: 0.796914	valid's binary_logloss: 0.231835
# [4200]	train's auc: 0.93769	train's binary_logloss: 0.172438	valid's auc: 0.796978	valid's binary_logloss: 0.231818
# [4400]	train's auc: 0.941123	train's binary_logloss: 0.170264	valid's auc: 0.797082	valid's binary_logloss: 0.231785
# [4600]	train's auc: 0.94445	train's binary_logloss: 0.168128	valid's auc: 0.797196	valid's binary_logloss: 0.231744
# Early stopping, best iteration is:
# [4584]	train's auc: 0.944174	train's binary_logloss: 0.168301	valid's auc: 0.797197	valid's binary_logloss: 0.231741
# C:\Users\sakib\anaconda3\envs\CSE499\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=-1 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [200]	train's auc: 0.77965	train's binary_logloss: 0.248434	valid's auc: 0.762643	valid's binary_logloss: 0.251117
# [400]	train's auc: 0.803343	train's binary_logloss: 0.236569	valid's auc: 0.77326	valid's binary_logloss: 0.243528
# [600]	train's auc: 0.819443	train's binary_logloss: 0.229068	valid's auc: 0.780479	valid's binary_logloss: 0.23985
# [800]	train's auc: 0.831563	train's binary_logloss: 0.223395	valid's auc: 0.78531	valid's binary_logloss: 0.237685
# [1000]	train's auc: 0.841744	train's binary_logloss: 0.218711	valid's auc: 0.788647	valid's binary_logloss: 0.236284
# [1200]	train's auc: 0.851042	train's binary_logloss: 0.214581	valid's auc: 0.790942	valid's binary_logloss: 0.23538
# [1400]	train's auc: 0.859573	train's binary_logloss: 0.210788	valid's auc: 0.792895	valid's binary_logloss: 0.234644
# [1600]	train's auc: 0.8675	train's binary_logloss: 0.207253	valid's auc: 0.794331	valid's binary_logloss: 0.234123
# [1800]	train's auc: 0.874908	train's binary_logloss: 0.203924	valid's auc: 0.795323	valid's binary_logloss: 0.233764
# [2000]	train's auc: 0.882006	train's binary_logloss: 0.200752	valid's auc: 0.79617	valid's binary_logloss: 0.233452
# [2200]	train's auc: 0.888614	train's binary_logloss: 0.197734	valid's auc: 0.796929	valid's binary_logloss: 0.233183
# [2400]	train's auc: 0.894821	train's binary_logloss: 0.194849	valid's auc: 0.797421	valid's binary_logloss: 0.233001
# [2600]	train's auc: 0.900627	train's binary_logloss: 0.192089	valid's auc: 0.79785	valid's binary_logloss: 0.232842
# [2800]	train's auc: 0.906221	train's binary_logloss: 0.189377	valid's auc: 0.798191	valid's binary_logloss: 0.232717
# [3000]	train's auc: 0.911486	train's binary_logloss: 0.186761	valid's auc: 0.798544	valid's binary_logloss: 0.232594
# [3200]	train's auc: 0.916268	train's binary_logloss: 0.184251	valid's auc: 0.798881	valid's binary_logloss: 0.23247
# [3400]	train's auc: 0.920884	train's binary_logloss: 0.181795	valid's auc: 0.799123	valid's binary_logloss: 0.232382
# [3600]	train's auc: 0.925262	train's binary_logloss: 0.179379	valid's auc: 0.799327	valid's binary_logloss: 0.232309
# [3800]	train's auc: 0.92933	train's binary_logloss: 0.177052	valid's auc: 0.79958	valid's binary_logloss: 0.232219
# [4000]	train's auc: 0.93333	train's binary_logloss: 0.174764	valid's auc: 0.799737	valid's binary_logloss: 0.232171
# [4200]	train's auc: 0.936979	train's binary_logloss: 0.172547	valid's auc: 0.799892	valid's binary_logloss: 0.232114
# [4400]	train's auc: 0.940321	train's binary_logloss: 0.170407	valid's auc: 0.80004	valid's binary_logloss: 0.232068
# [4600]	train's auc: 0.943544	train's binary_logloss: 0.168306	valid's auc: 0.80014	valid's binary_logloss: 0.232046
# [4800]	train's auc: 0.946604	train's binary_logloss: 0.16624	valid's auc: 0.800267	valid's binary_logloss: 0.232003
# [5000]	train's auc: 0.949552	train's binary_logloss: 0.164208	valid's auc: 0.800405	valid's binary_logloss: 0.231975
# [5200]	train's auc: 0.952346	train's binary_logloss: 0.162195	valid's auc: 0.800451	valid's binary_logloss: 0.231972
# Early stopping, best iteration is:
# [5140]	train's auc: 0.951518	train's binary_logloss: 0.162798	valid's auc: 0.80049	valid's binary_logloss: 0.231963
# C:\Users\sakib\anaconda3\envs\CSE499\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=-1 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [200]	train's auc: 0.779876	train's binary_logloss: 0.247991	valid's auc: 0.756889	valid's binary_logloss: 0.252947
# [400]	train's auc: 0.803321	train's binary_logloss: 0.236187	valid's auc: 0.768414	valid's binary_logloss: 0.245484
# [600]	train's auc: 0.819604	train's binary_logloss: 0.228698	valid's auc: 0.776588	valid's binary_logloss: 0.241766
# [800]	train's auc: 0.831764	train's binary_logloss: 0.223059	valid's auc: 0.78185	valid's binary_logloss: 0.239576
# [1000]	train's auc: 0.842218	train's binary_logloss: 0.218343	valid's auc: 0.785295	valid's binary_logloss: 0.238168
# [1200]	train's auc: 0.851559	train's binary_logloss: 0.214179	valid's auc: 0.787845	valid's binary_logloss: 0.237184
# [1400]	train's auc: 0.860244	train's binary_logloss: 0.210366	valid's auc: 0.789567	valid's binary_logloss: 0.236508
# [1600]	train's auc: 0.86815	train's binary_logloss: 0.206826	valid's auc: 0.790798	valid's binary_logloss: 0.23602
# [1800]	train's auc: 0.875873	train's binary_logloss: 0.203447	valid's auc: 0.791962	valid's binary_logloss: 0.235585
# [2000]	train's auc: 0.882928	train's binary_logloss: 0.200253	valid's auc: 0.792826	valid's binary_logloss: 0.23527
# [2200]	train's auc: 0.889735	train's binary_logloss: 0.197186	valid's auc: 0.793692	valid's binary_logloss: 0.234966
# [2400]	train's auc: 0.895882	train's binary_logloss: 0.194288	valid's auc: 0.79431	valid's binary_logloss: 0.234739
# [2600]	train's auc: 0.901666	train's binary_logloss: 0.191492	valid's auc: 0.794778	valid's binary_logloss: 0.234549
# [2800]	train's auc: 0.907116	train's binary_logloss: 0.188787	valid's auc: 0.795279	valid's binary_logloss: 0.234364
# [3000]	train's auc: 0.912376	train's binary_logloss: 0.186166	valid's auc: 0.795693	valid's binary_logloss: 0.234223
# [3200]	train's auc: 0.9172	train's binary_logloss: 0.183633	valid's auc: 0.795969	valid's binary_logloss: 0.234116
# [3400]	train's auc: 0.921865	train's binary_logloss: 0.181156	valid's auc: 0.796183	valid's binary_logloss: 0.234032
# [3600]	train's auc: 0.926179	train's binary_logloss: 0.178752	valid's auc: 0.796474	valid's binary_logloss: 0.233934
# [3800]	train's auc: 0.930189	train's binary_logloss: 0.176441	valid's auc: 0.796702	valid's binary_logloss: 0.233872
# [4000]	train's auc: 0.934027	train's binary_logloss: 0.174168	valid's auc: 0.796827	valid's binary_logloss: 0.233827
# Early stopping, best iteration is:
# [4079]	train's auc: 0.935443	train's binary_logloss: 0.173301	valid's auc: 0.796923	valid's binary_logloss: 0.233801
# C:\Users\sakib\anaconda3\envs\CSE499\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=-1 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [200]	train's auc: 0.778792	train's binary_logloss: 0.24814	valid's auc: 0.765007	valid's binary_logloss: 0.252606
# [400]	train's auc: 0.802636	train's binary_logloss: 0.236403	valid's auc: 0.776865	valid's binary_logloss: 0.244531
# [600]	train's auc: 0.818754	train's binary_logloss: 0.228959	valid's auc: 0.78492	valid's binary_logloss: 0.240466
# [800]	train's auc: 0.830908	train's binary_logloss: 0.223313	valid's auc: 0.7896	valid's binary_logloss: 0.238154
# [1000]	train's auc: 0.841304	train's binary_logloss: 0.218619	valid's auc: 0.79264	valid's binary_logloss: 0.236717
# [1200]	train's auc: 0.850594	train's binary_logloss: 0.214475	valid's auc: 0.794666	valid's binary_logloss: 0.235766
# [1400]	train's auc: 0.859299	train's binary_logloss: 0.210657	valid's auc: 0.796015	valid's binary_logloss: 0.235144
# [1600]	train's auc: 0.867351	train's binary_logloss: 0.207102	valid's auc: 0.796983	valid's binary_logloss: 0.234695
# [1800]	train's auc: 0.875018	train's binary_logloss: 0.203729	valid's auc: 0.797624	valid's binary_logloss: 0.234403
# [2000]	train's auc: 0.882148	train's binary_logloss: 0.200535	valid's auc: 0.798214	valid's binary_logloss: 0.234131
# [2200]	train's auc: 0.889011	train's binary_logloss: 0.197453	valid's auc: 0.798647	valid's binary_logloss: 0.233938
# [2400]	train's auc: 0.895343	train's binary_logloss: 0.194526	valid's auc: 0.799051	valid's binary_logloss: 0.233761
# [2600]	train's auc: 0.901442	train's binary_logloss: 0.19167	valid's auc: 0.799415	valid's binary_logloss: 0.233617
# [2800]	train's auc: 0.907087	train's binary_logloss: 0.188913	valid's auc: 0.799648	valid's binary_logloss: 0.233511
# [3000]	train's auc: 0.912411	train's binary_logloss: 0.186266	valid's auc: 0.79988	valid's binary_logloss: 0.233415
# Early stopping, best iteration is:
# [3035]	train's auc: 0.913268	train's binary_logloss: 0.185809	valid's auc: 0.799962	valid's binary_logloss: 0.233386
# C:\Users\sakib\anaconda3\envs\CSE499\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=-1 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [200]	train's auc: 0.780503	train's binary_logloss: 0.247396	valid's auc: 0.75532	valid's binary_logloss: 0.255279
# [400]	train's auc: 0.804043	train's binary_logloss: 0.235627	valid's auc: 0.767337	valid's binary_logloss: 0.24767
# [600]	train's auc: 0.820112	train's binary_logloss: 0.228213	valid's auc: 0.775289	valid's binary_logloss: 0.24389
# [800]	train's auc: 0.83215	train's binary_logloss: 0.222571	valid's auc: 0.780682	valid's binary_logloss: 0.241564
# [1000]	train's auc: 0.842442	train's binary_logloss: 0.217885	valid's auc: 0.784111	valid's binary_logloss: 0.240121
# [1200]	train's auc: 0.851916	train's binary_logloss: 0.213716	valid's auc: 0.786626	valid's binary_logloss: 0.239111
# [1400]	train's auc: 0.860587	train's binary_logloss: 0.209911	valid's auc: 0.788821	valid's binary_logloss: 0.238291
# [1600]	train's auc: 0.868347	train's binary_logloss: 0.206412	valid's auc: 0.790179	valid's binary_logloss: 0.237754
# [1800]	train's auc: 0.875694	train's binary_logloss: 0.203094	valid's auc: 0.791158	valid's binary_logloss: 0.237356
# [2000]	train's auc: 0.882658	train's binary_logloss: 0.199926	valid's auc: 0.791959	valid's binary_logloss: 0.237039
# [2200]	train's auc: 0.889211	train's binary_logloss: 0.196914	valid's auc: 0.792661	valid's binary_logloss: 0.236772
# [2400]	train's auc: 0.895354	train's binary_logloss: 0.194025	valid's auc: 0.792985	valid's binary_logloss: 0.236624
# [2600]	train's auc: 0.901333	train's binary_logloss: 0.191238	valid's auc: 0.79339	valid's binary_logloss: 0.236483
# [2800]	train's auc: 0.90684	train's binary_logloss: 0.188535	valid's auc: 0.793747	valid's binary_logloss: 0.236357
# [3000]	train's auc: 0.911965	train's binary_logloss: 0.185933	valid's auc: 0.794022	valid's binary_logloss: 0.236256
# [3200]	train's auc: 0.916909	train's binary_logloss: 0.183397	valid's auc: 0.794181	valid's binary_logloss: 0.236185
# [3400]	train's auc: 0.921583	train's binary_logloss: 0.180923	valid's auc: 0.794367	valid's binary_logloss: 0.23611
# [3600]	train's auc: 0.925957	train's binary_logloss: 0.178517	valid's auc: 0.794663	valid's binary_logloss: 0.236002
# [3800]	train's auc: 0.930053	train's binary_logloss: 0.176186	valid's auc: 0.794857	valid's binary_logloss: 0.23594
# [4000]	train's auc: 0.93401	train's binary_logloss: 0.173882	valid's auc: 0.795046	valid's binary_logloss: 0.235858
# [4200]	train's auc: 0.937694	train's binary_logloss: 0.171646	valid's auc: 0.795096	valid's binary_logloss: 0.235841
# Early stopping, best iteration is:
# [4160]	train's auc: 0.936977	train's binary_logloss: 0.172092	valid's auc: 0.795124	valid's binary_logloss: 0.235832
# LightGBM metrics
#       fold     train     valid
# 0        0  0.944174  0.797197
# 1        1  0.951518  0.800490
# 2        2  0.935443  0.796923
# 3        3  0.913268  0.799962
# 4        4  0.936977  0.795124
# 5  overall  0.936276  0.797894

# %%
submission.to_csv('lgb.csv', index = False)
